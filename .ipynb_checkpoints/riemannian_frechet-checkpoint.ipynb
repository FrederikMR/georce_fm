# %% [markdown]
# # Riemannian Fréchet Mean

# %%
#Modules
import jax.numpy as jnp
import jax.random as jrandom
from jax import vmap

from abc import ABC

import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.ticker as tkr

import os

from geometry.riemannian.manifolds import S2 as RS2
from geometry.riemannian.frechet_mean import GEORCE_FM, GEORCE_AdaFM
from geometry.riemannian.manifolds import nEllipsoid, nSphere, nParaboloid, nEuclidean, T2, RiemannianManifold, FisherRaoGeometry

# %%
plt.rcParams.update({'font.size': 25})
cbformat = tkr.ScalarFormatter()   # create the formatter
cbformat.set_powerlimits((-2,2))

# %%
figure_path = '../figures/riemannian/frechet/'
seed = 2712

# %%
if not (os.path.exists(figure_path)):
    os.makedirs(figure_path)

# %% [markdown]
# ## Conceptual Method Figure

# %% [markdown]
# ### Generate data

# %%
N_data = 10

# %%
M = nSphere(dim=2)

# %%
theta = jnp.linspace(0, 2*jnp.pi, N_data, endpoint=False)
x_obs = 0.1*jnp.vstack((jnp.cos(theta), jnp.sin(theta), jnp.ones(N_data))).T
x_obs = x_obs.T/jnp.linalg.norm(x_obs, axis=1)
x_obs = x_obs.T

z_obs = vmap(M.invf)(x_obs)

# %% [markdown]
# ### Computing Fréchet Mean

# %%
iters = 3
T = 100
tol = 1e-4
rho = 0.5

# %%
FrechetMean = GEORCE_FM(M=M,
                        init_fun=None,
                        T=T,
                        max_iter=iters,
                        tol = tol,
                        line_search_params={'rho': rho},
                       )

# %%
fmean = FrechetMean(z_obs, z_mu_init=z_obs[0], step="for")

# %%
zt_init, *_ = vmap(FrechetMean.init_curve, in_axes=(0,None))(z_obs, z_obs[0])
xt_init = vmap(vmap(M.f))(zt_init)
obj_init = M.length_frechet(zt_init[:,::-1], z_obs, z_obs[0])

# %%
xt_geodesics = vmap(vmap(vmap(M.f)))(fmean[1])
xt_fm = vmap(M.f)(fmean[0])
dist = vmap(lambda zt, z_mu: M.length_frechet(zt, z_obs, z_mu))(fmean[1], fmean[0])

# %% [markdown]
# ### Plotting

# %%
class EllipsoidPlot(ABC):
    def __init__(self, params=jnp.linspace(0.5,1.0,3)[::-1]):
        
        self.params = params

    def grid(self, n_points:int=100):
        
        theta = jnp.linspace(0.0, jnp.pi*1, n_points)
        phi   = jnp.linspace(0.0, jnp.pi*2, n_points)

        # Creating the coordinate grid for the unit sphere.
        x1 = jnp.outer(jnp.sin(theta), jnp.cos(phi))
        x2 = jnp.outer(jnp.sin(theta), jnp.sin(phi))
        x3 = jnp.outer(jnp.cos(theta), jnp.ones(n_points))
        
        return self.params[0]*x1,self.params[1]*x2,self.params[2]*x3

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create figure with adjusted aspect ratio
fig = plt.figure(figsize=(20, 5))  # Reduce horizontal stretch

# Generate the sphere once
plot_sphere = EllipsoidPlot(params=jnp.ones(3))
x1, x2, x3 = plot_sphere.grid(100)

# Shared settings for 3D plots
def setup_3d_ax(ax):
    ax.plot_surface(
        x1, x2, x3,
        color='lightblue',
        rstride=1, cstride=1,
        alpha=0.5,
        edgecolor='none',  # No grid lines on surface
        shade=True          # Adds lighting effect for depth
    )
    ax.set_box_aspect([1,1,1])
    ax.set_xlim([-1.0, 1.0])
    ax.set_ylim([-1.0, 1.0])
    ax.set_zlim([-1.0, 1.0])
    ax.set_axis_off()
    ax.view_init(elev=60., azim=0.)
    #ax.view_init(elev=30., azim=45)

# Subplot 1: Initialization
ax = fig.add_subplot(1, 4, 1, projection='3d')
setup_3d_ax(ax)
ax.scatter(x_obs[:,0], x_obs[:,1], x_obs[:,2], color='black', alpha=1.0, s=100)
ax.scatter(x_obs[0,0], x_obs[0,1], x_obs[0,2], color='blue', alpha=1.0, s=250)
for v1 in xt_init:
    ax.plot(v1[:,0], v1[:,1], v1[:,2], color='red', alpha=1.0, linewidth=2.5)
ax.set_title(f"Initialization \n MOI = {obj_init:.2f}", y=1.0, pad=-20, fontsize=15)

# Iterations
for i in range(3):
    ax = fig.add_subplot(1, 4, i + 2, projection='3d')
    setup_3d_ax(ax)
    ax.scatter(x_obs[:,0], x_obs[:,1], x_obs[:,2], color='black', alpha=1.0, s=100)
    ax.scatter(xt_fm[i][0], xt_fm[i][1], xt_fm[i][2], color='blue', alpha=1.0, s=250)
    for v1 in xt_geodesics[i]:
        ax.plot(v1[:,0], v1[:,1], v1[:,2], color='red', alpha=1.0, linewidth=2.5)
    ax.set_title(f"Iteration {i+1} \n MOI = {dist[i]:.2f}", y=1.0, pad=-20, fontsize=15)

ax.scatter([],[],[], color="black", alpha=1.0, s=100, label="Data Points")
ax.scatter([],[],[], color="blue", alpha=1.0, s=250, label="Fréchet Mean")
ax.plot([],[],[], color="red", alpha=1.0, linewidth=2.5, label=r"Geodesics")

lines_labels = [ax.get_legend_handles_labels()]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
fig.legend(lines, labels, loc=(0.325, 0.06), ncol=3, fontsize=15)

fig.tight_layout()
fig.savefig(f'{figure_path}conceptual_riemannian_frechet.pdf', format='pdf', bbox_inches='tight')
plt.show()

# %%
#fig = plt.figure(figsize=(40,10))
#
#plotting sphere
#plot_sphere = EllipsoidPlot(params=jnp.ones(3))
#x1,x2,x3 = plot_sphere.grid(100)
#
#ax = fig.add_subplot(1,4,1, projection='3d')
#ax.plot_surface(x1, x2, x3, color='cyan', rstride=1, cstride=1, alpha=0.2)
#
#ax.scatter(x_obs[:,0], x_obs[:,1], x_obs[:,2], color='black', alpha=1.0, s=250)
#ax.scatter(x_obs[0,0], x_obs[0,1], x_obs[0,2], color='blue', alpha=1.0, s=500)
#for v1 in xt_init:
#    ax.plot(v1[:,0], v1[:,1], v1[:,2], color='red', alpha=1.0, linewidth=5.0)
#ax.set_box_aspect([1,1,1])
#ax.set_xlim([-1.0,1.0])
#ax.set_ylim([-1.0,1.0])
#ax.set_zlim([-1.0,1.0])
#ax.set_axis_off()
#ax.view_init(elev=60., azim=0.)
#ax.set_title(f"Initilization \n MOI = {obj_init:.2f}", y=1.0, pad=-20, fontsize=30)
#
#for i in range(3):
#    ax = fig.add_subplot(1,4,i+2, projection='3d')
#    ax.plot_surface(x1, x2, x3, color='cyan', rstride=1, cstride=1, alpha=0.2)
#
#    ax.scatter(x_obs[:,0], x_obs[:,1], x_obs[:,2], color='black', alpha=1.0, s=250)
#    ax.scatter(xt_fm[i][0], xt_fm[i][1], xt_fm[i][2], color='blue', alpha=1.0, s=500)
#    for v1 in xt_geodesics[i]:
#        ax.plot(v1[:,0], v1[:,1], v1[:,2], color='red', alpha=1.0, linewidth=5.0)
#    ax.set_box_aspect([1,1,1])
#    ax.set_xlim([-1.0,1.0])
#    ax.set_ylim([-1.0,1.0])
#    ax.set_zlim([-1.0,1.0])
#    ax.set_axis_off()
#    ax.set_title(f"Iteration {i+1} \n MOI = {dist[i]:.2f}", y=1.0, pad=-20, fontsize=30)
#    ax.view_init(elev=60., azim=0.)
#    
#ax.scatter([],[],[], color="black", alpha=1.0, s=250, label="Data Points")
#ax.scatter([],[],[], color="blue", alpha=1.0, s=500, label="Fréchet Mean")
#ax.plot([],[],[], color="red", alpha=1.0, linewidth=5.0, label=r"Geodesics")
#
#lines_labels = [ax.get_legend_handles_labels()]
#lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
#fig.legend(lines, labels, loc=(0.35, 0.05), ncol=3, fontsize=30)
#    
#fig.tight_layout()
#
#save_path = f'{figure_path}conceptual_riemannian_frechet.pdf'
#fig.savefig(save_path, format='pdf', pad_inches=0.0, bbox_inches='tight')
#
#plt.show()

# %% [markdown]
# ## Illustrating Non-uniqueness

# %%
theta = jnp.linspace(0, 2*jnp.pi, N_data, endpoint=False)
x_equator_obs = jnp.vstack((jnp.cos(theta), jnp.sin(theta), jnp.zeros(N_data))).T
x_equator_obs = x_equator_obs.T/jnp.linalg.norm(x_equator_obs, axis=1)
x_equator_obs = x_equator_obs.T

mean1 = jnp.array([0.0, 0.0, 1.0])
mean2 = jnp.array([0.0, 0.0, -1.0])

# %%
theta = jnp.linspace(0, 2*jnp.pi, 1000, endpoint=False)
x_equator_line = jnp.vstack((jnp.cos(theta), jnp.sin(theta), jnp.zeros(1000))).T
x_equator_line = x_equator_line.T/jnp.linalg.norm(x_equator_line, axis=1)
x_equator_line = x_equator_line.T

# %%
theta = jnp.linspace(0, 2*jnp.pi, 1000, endpoint=False)
x_north_line = 0.1*jnp.vstack((jnp.cos(theta), jnp.sin(theta), jnp.ones(1000))).T
x_north_line = x_north_line.T/jnp.linalg.norm(x_north_line, axis=1)
x_north_line = x_north_line.T

# %%
geodesic1 = vmap(M.Geodesic, in_axes=(None, 0))(mean1, x_equator_obs)
geodesic2 = vmap(M.Geodesic, in_axes=(None, 0))(mean2, x_equator_obs)

# %%
theta = jnp.linspace(0, 2.01*jnp.pi, 100, endpoint=False)
radius = jnp.linspace(0, 0.1, 100, endpoint=False)
theta, radius = jnp.meshgrid(theta, radius)

x1_north = vmap(vmap(lambda v,r: r*jnp.cos(v)))(theta, radius)
x2_north = vmap(vmap(lambda v,r: r*jnp.sin(v)))(theta, radius)
x3_north = jnp.ones_like(x1_north)

# %%
theta = jnp.linspace(0, 2.01*jnp.pi, 100, endpoint=False)
radius = 0.1

x1_open_line = vmap(lambda v: radius*jnp.cos(v))(theta)
x2_open_line = vmap(lambda v: radius*jnp.sin(v))(theta)
x3_open_line = jnp.ones_like(x1_north)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(20, 10))

# Generate the base sphere
plot_sphere = EllipsoidPlot(params=jnp.ones(3))
x1, x2, x3 = plot_sphere.grid(100)

# Shared 3D axis setup
def setup_3d_ax(ax):
    ax.plot_surface(
        x1, x2, x3,
        color='lightblue',
        rstride=1, cstride=1,
        alpha=0.5,
        edgecolor='none',
        shade=True
    )
    ax.set_box_aspect([1,1,1])
    ax.set_xlim([-1.0, 1.0])
    ax.set_ylim([-1.0, 1.0])
    ax.set_zlim([-1.0, 1.0])
    ax.set_axis_off()
    ax.view_init(elev=60., azim=0.)

# ---------- First subplot ----------
ax = fig.add_subplot(1, 2, 1, projection='3d')
setup_3d_ax(ax)

ax.scatter(x_equator_obs[:,0], x_equator_obs[:,1], x_equator_obs[:,2], color='black', alpha=1.0, s=100)
ax.scatter(mean1[0], mean1[1], mean1[2], color='blue', alpha=1.0, s=250)
ax.scatter(mean2[0], mean2[1], mean2[2], color='blue', alpha=1.0, s=250)

for g1, g2 in zip(geodesic1, geodesic2):
    ax.plot(g1[:,0], g1[:,1], g1[:,2], color='red', alpha=1.0, linewidth=2.5)
    ax.plot(g2[:,0], g2[:,1], g2[:,2], color='green', alpha=1.0, linewidth=2.5)

ax.plot(x_equator_line[:,0], x_equator_line[:,1], x_equator_line[:,2], color='black', alpha=1.0, linewidth=2.5)

# ---------- Second subplot ----------
ax = fig.add_subplot(1, 2, 2, projection='3d')
setup_3d_ax(ax)

# Add the yellow "north" patch
ax.plot_surface(x1_north, x2_north, x3_north,
                color='yellow', alpha=1.0, edgecolor='none', shade=True)

ax.scatter(x_obs[:,0], x_obs[:,1], x_obs[:,2], color='black', alpha=1.0, s=100)
ax.plot(x_north_line[:,0], x_north_line[:,1], x_north_line[:,2], color='black', alpha=1.0, linewidth=2.5)
ax.plot(x1_open_line, x2_open_line, x3_open_line, color='black', alpha=1.0, linewidth=2.5)

fig.tight_layout()
save_path = f'{figure_path}riemannian_non_uniqueness.pdf'
fig.savefig(save_path, format='pdf', pad_inches=0.1, bbox_inches='tight')
plt.show()

# %%
#fig = plt.figure(figsize=(20,10))
#
#plotting sphere
#plot_sphere = EllipsoidPlot(params=jnp.ones(3))
#x1,x2,x3 = plot_sphere.grid(100)
#
#ax = fig.add_subplot(1,2,1, projection='3d')
#ax.plot_surface(x1, x2, x3, color='cyan', rstride=1, cstride=1, alpha=0.2)
#ax.scatter(x_equator_obs[:,0], x_equator_obs[:,1], x_equator_obs[:,2], color='black', alpha=1.0, s=250)
#ax.scatter(mean1[0], mean1[1], mean1[2], color='blue', alpha=1.0, s=500)
#ax.scatter(mean2[0], mean2[1], mean2[2], color='blue', alpha=1.0, s=500)
#for g1, g2 in zip(geodesic1, geodesic2):
#    ax.plot(g1[:,0], g1[:,1], g1[:,2], color='red', alpha=1.0, linewidth=5.0)
#    ax.plot(g2[:,0], g2[:,1], g2[:,2], color='green', alpha=1.0, linewidth=5.0)
#
#ax.plot(x_equator_line[:,0], x_equator_line[:,1], x_equator_line[:,2], color='black', alpha=1.0, linewidth=2.5)
#ax.set_box_aspect([1,1,1])
#ax.set_xlim([-1.0,1.0])
#ax.set_ylim([-1.0,1.0])
#ax.set_zlim([-1.0,1.0])
#ax.set_axis_off()
#ax.view_init(elev=60., azim=0.)
#
#plotting sphere
#plot_sphere = EllipsoidPlot(params=jnp.ones(3))
#x1,x2,x3 = plot_sphere.grid(100)
#
#ax = fig.add_subplot(1,2,2, projection='3d')
#ax.plot_surface(x1_north, x2_north, x3_north, color='yellow', rstride=1, cstride=1, alpha=1.0)
#ax.plot_surface(x1, x2, x3, color='cyan', rstride=1, cstride=1, alpha=0.2)
#ax.scatter(x_obs[:,0], x_obs[:,1], x_obs[:,2], color='black', alpha=1.0, s=250)
#ax.plot(x_north_line[:,0], x_north_line[:,1], x_north_line[:,2], color='black', alpha=1.0, linewidth=2.5)
#ax.plot(x1_open_line, x2_open_line, x3_open_line, color='black', alpha=1.0, linewidth=2.5)
#ax.set_box_aspect([1,1,1])
#ax.set_xlim([-1.0,1.0])
#ax.set_ylim([-1.0,1.0])
#ax.set_zlim([-1.0,1.0])
#ax.set_axis_off()
#ax.view_init(elev=60., azim=0.)
#
#fig.tight_layout()
#
#save_path = f'{figure_path}riemannian_non_uniqueness.pdf'
#fig.savefig(save_path, format='pdf', pad_inches=0.1, bbox_inches='tight')
#
#plt.show()

# %% [markdown]
# ## Information Geometry with Fisher-Rao metric

# %%
N_data = 10

# %%
max_iter = 1000
T = 100
tol = 1e-4
rho = 0.95
std = 0.1

# %% [markdown]
# ### Gaussian Distribution

# %% [markdown]
# #### Generate Data

# %%
M = FisherRaoGeometry(distribution='Gaussian')
z0 = jnp.array([-1.0, 0.5])
z1 = jnp.array([1.0, 1.0])

# %%
key = jrandom.PRNGKey(seed)
eps = std*jrandom.normal(key, shape=(N_data//2, M.dim))

# %%
data1 = z0 + jnp.abs(eps)
data2 = z1 + jnp.abs(eps)
gaussian_data = jnp.vstack((data1, data2))

# %% [markdown]
# #### Computing Fréchet Mean

# %%
FrechetMean = GEORCE_FM(M=M,
                        init_fun=None,
                        T=T,
                        max_iter=max_iter,
                        tol = tol,
                        line_search_params={'rho': rho},
                       )

# %%
fgaussian = FrechetMean(gaussian_data, step="while")

# %%
gaussian_dist = M.length_frechet(fgaussian[1], gaussian_data, fgaussian[0])

# %%
gaussian_pdf = vmap(lambda mu,sigma: vmap(lambda x: \
                                          M.pdf_gaussian(x,
                                                         jnp.hstack((mu,sigma))))(jnp.linspace(mu-3*sigma,
                                                                                               mu+3*sigma,
                                                                                               100)))(gaussian_data[:,0],
                                                                                                      gaussian_data[:,1])

gaussian_grid = vmap(lambda mu, sigma: jnp.linspace(mu-3*sigma,
                                                    mu+3*sigma,
                                                    100))(gaussian_data[:,0],
                                                          gaussian_data[:,1])

# %%
mu, sigma = fgaussian[0][0], fgaussian[0][1]
gaussian_fmpdf = vmap(lambda x: M.pdf_gaussian(x,jnp.hstack((mu,sigma))))(jnp.linspace(mu-3*sigma,
                                                                          mu+3*sigma,
                                                                          100))
gaussian_fmgrid = jnp.linspace(mu-3*sigma,mu+3*sigma,100)

# %% [markdown]
# ### Frechet Distribution

# %%
M = FisherRaoGeometry(distribution='Frechet')
z0 = jnp.array([0.5, 0.5])
z1 = jnp.array([1.0, 1.0])

# %%
key = jrandom.PRNGKey(seed)
eps = std*jrandom.normal(key, shape=(N_data//2, M.dim))

# %%
data1 = z0 + jnp.abs(eps)
data2 = z1 + jnp.abs(eps)
frechet_data = jnp.vstack((data1, data2))

# %% [markdown]
# #### Computing Fréchet Mean

# %%
FrechetMean = GEORCE_FM(M=M,
                        init_fun=None,
                        T=T,
                        max_iter=max_iter,
                        tol = tol,
                        line_search_params={'rho': rho},
                       )

# %%
ffrechet = FrechetMean(frechet_data, step="while")

# %%
frechet_dist = M.length_frechet(ffrechet[1], frechet_data, ffrechet[0])

# %%
frechet_pdf = vmap(lambda beta,lam: vmap(lambda x: \
                                 M.pdf_frechet(x,jnp.hstack((beta,lam))))(jnp.linspace(0.01,
                                                                                    3.0,
                                                                                        100)))(frechet_data[:,0],
                                                                                               frechet_data[:,1])
frechet_grid = vmap(lambda beta, lam: jnp.linspace(0.01,
                                             3.0,
                                             100))(frechet_data[:,0],
                                                   frechet_data[:,1])

# %%
beta, lam = ffrechet[0][0], ffrechet[0][1]
frechet_fmpdf =  vmap(lambda x: M.pdf_frechet(x,jnp.hstack((beta,lam))))(jnp.linspace(0.01,3.0,100))
frechet_fmgrid = jnp.linspace(0.01,3.0,100)

# %% [markdown]
# ### Cauchy Distribution

# %%
M = FisherRaoGeometry(distribution='Cauchy')
z0 = jnp.array([-1.0, 0.5])
z1 = jnp.array([1.0, 1.0])

# %%
key = jrandom.PRNGKey(seed)
eps = std*jrandom.normal(key, shape=(N_data//2, M.dim))

# %%
data1 = z0 + jnp.abs(eps)
data2 = z1 + jnp.abs(eps)
cauchy_data = jnp.vstack((data1, data2))

# %% [markdown]
# #### Computing Fréchet Mean

# %%
FrechetMean = GEORCE_FM(M=M,
                        init_fun=None,
                        T=T,
                        max_iter=max_iter,
                        tol = 1e-4,
                        line_search_params={'rho': rho},
                       )

# %%
fcauchy = FrechetMean(cauchy_data, step="while")

# %%
cauchy_dist = M.length_frechet(fcauchy[1], cauchy_data, fcauchy[0])

# %%
cauchy_pdf = vmap(lambda mu,sigma: vmap(lambda x: \
                                          M.pdf_cauchy(x,
                                                       jnp.hstack((mu,sigma))))(jnp.linspace(mu-3*sigma,
                                                                                             mu+3*sigma,
                                                                                             100)))(cauchy_data[:,0],
                                                                                                    cauchy_data[:,1])
cauchy_grid = vmap(lambda mu, sigma: jnp.linspace(mu-3*sigma,
                                                  mu+3*sigma,
                                                  100))(cauchy_data[:,0],
                                                        cauchy_data[:,1])

# %%
mu, sigma = fcauchy[0][0], fcauchy[0][1]
cauchy_fmpdf =  vmap(lambda x: M.pdf_cauchy(x,jnp.hstack((mu,sigma))))(jnp.linspace(mu-3*sigma,
                                                                                    mu+3*sigma,
                                                                                    100))
cauchy_fmgrid = jnp.linspace(mu-3*sigma,mu+3*sigma,100)

# %% [markdown]
# ### Pareto Distribution

# %%
M = FisherRaoGeometry(distribution='Pareto')
z0 = jnp.array([0.5, 0.5])
z1 = jnp.array([1.0, 1.0])

# %%
key = jrandom.PRNGKey(seed)
eps = 0.5*jrandom.normal(key, shape=(N_data//2, M.dim))

# %%
data1 = z0 + jnp.abs(eps)
data2 = z1 + jnp.abs(eps)
pareto_data = jnp.vstack((data1, data2))

# %% [markdown]
# #### Computing Fréchet Mean

# %%
FrechetMean = GEORCE_FM(M=M,
                        init_fun=None,
                        T=T,
                        max_iter=max_iter,
                        tol = tol,
                        line_search_params={'rho': rho},
                       )

# %%
fpareto = FrechetMean(pareto_data, step="while")

# %%
pareto_dist = M.length_frechet(fpareto[1], pareto_data, fpareto[0])

# %%
pareto_pdf = vmap(lambda theta,alpha: vmap(lambda x: \
                                 M.pdf_pareto(x,jnp.hstack((theta,alpha))))(jnp.linspace(0.5,
                                                                                        2.0,
                                                                                        100)))(pareto_data[:,0],
                                                                                               pareto_data[:,1])
pareto_grid = vmap(lambda theta, alpha: jnp.linspace(0.5,
                                             2.0,
                                             100))(pareto_data[:,0],
                                                   pareto_data[:,1])

# %%
theta, alpha = fpareto[0][0], fpareto[0][1]
pareto_fmpdf =  vmap(lambda x: M.pdf_pareto(x,jnp.hstack((theta,alpha))))(jnp.linspace(0.5,
                                                                                        2.0,
                                                                                        100))
pareto_fmgrid = jnp.linspace(0.5,2.0,100)

# %% [markdown]
# ### Plotting

# %%
fig = plt.figure(figsize=(40,10))

#Gaussian
ax = fig.add_subplot(141)
for grid, pdf in zip(gaussian_grid, gaussian_pdf):
    ax.plot(grid, pdf, color='black', linewidth=2.0)
    ax.fill_between(grid, 
                    pdf,
                    alpha=0.1,
                    )
    
ax.plot([], [], color='black', linewidth=5.0, label="Data Points")
ax.plot(gaussian_fmgrid, gaussian_fmpdf, color='blue', linewidth=5.0, label="GEORCE-FM" + "\n" + f"-Iterations: {fgaussian[-1]}" + "\n" + f"-MOI: {gaussian_dist:.2f}")
ax.fill_between(gaussian_fmgrid, 
                gaussian_fmpdf,
                color="blue",
                alpha=0.5,
                )
ax.set_xlabel(f'$t$', fontsize=40)
ax.set_ylabel(f'Density', fontsize=40)
ax.legend(loc=2, prop={'size': 35})
ax.set_title(f'Gaussian Distribution', fontsize=50)
ax.grid(True)

#Frechet
ax = fig.add_subplot(142)
for grid, pdf in zip(frechet_grid, frechet_pdf):
    ax.plot(grid, pdf, color='black', linewidth=2.0)
    ax.fill_between(grid, 
                    pdf,
                    alpha=0.1,
                    )
    
ax.plot([], [], color='black', linewidth=5.0, label="Data Points")
ax.plot(frechet_fmgrid, frechet_fmpdf, color='blue', linewidth=5.0, label="GEORCE-FM" + "\n" + f"-Iterations: {ffrechet[-1]}" + "\n" + f"-MOI: {frechet_dist:.2f}")
ax.fill_between(frechet_fmgrid, 
                frechet_fmpdf,
                color="blue",
                alpha=0.5,
                )
ax.set_xlabel(f'$t$', fontsize=40)
ax.set_ylabel(f'Density', fontsize=40)
ax.legend(loc=2, prop={'size': 35})
ax.set_title(f'Frechet Distribution', fontsize=50)
ax.grid(True)

#Cauchy
ax = fig.add_subplot(143)
for grid, pdf in zip(cauchy_grid, cauchy_pdf):
    ax.plot(grid, pdf, color='black', linewidth=2.0)
    ax.fill_between(grid, 
                    pdf,
                    alpha=0.1,
                    )
    
ax.plot([], [], color='black', linewidth=5.0, label="Data Points")
ax.plot(cauchy_fmgrid, cauchy_fmpdf, color='blue', linewidth=5.0, label="GEORCE-FM" + "\n" + f"-Iterations: {fcauchy[-1]}" + "\n" + f"-MOI: {cauchy_dist:.2f}")
ax.fill_between(cauchy_fmgrid, 
                cauchy_fmpdf,
                color="blue",
                alpha=0.5,
                )
ax.set_xlabel(f'$t$', fontsize=40)
ax.set_ylabel(f'Density', fontsize=40)
ax.legend(loc=2, prop={'size': 35})
ax.set_title(f'Cauchy Distribution', fontsize=50)
ax.grid(True)

#Pareto
ax = fig.add_subplot(144)
for grid, pdf in zip(pareto_grid, pareto_pdf):
    ax.plot(grid, pdf, color='black', linewidth=2.0)
    ax.fill_between(grid, 
                    pdf,
                    alpha=0.1,
                    )
    
ax.plot([], [], color='black', linewidth=5.0, label="Data Points")
ax.plot(pareto_fmgrid, pareto_fmpdf, color='blue', linewidth=5.0, label="GEORCE-FM" + "\n" + f"-Iterations: {fpareto[-1]}" + "\n" + f"-MOI: {pareto_dist:.2f}")
ax.fill_between(pareto_fmgrid, 
                pareto_fmpdf,
                color="blue",
                alpha=0.5,
                )
ax.set_xlabel(f'$t$', fontsize=40)
ax.set_ylabel(f'Density', fontsize=40)
ax.legend(loc=2, prop={'size': 35})
ax.set_title(f'Pareto Distribution', fontsize=50)
ax.grid(True)

fig.tight_layout()
save_path = f'{figure_path}information_geometry_frechet_mean.pdf'
fig.savefig(save_path, format='pdf', pad_inches=0.1, bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Conceptual of illustration of charts in GEORCE

# %%
iters = 1000
T = 100
tol = 1e-4
rho = 0.5

# %%
M = RS2()

# %%
N_data = 10

# %%
theta = jnp.linspace(0, 2*jnp.pi, N_data, endpoint=False)
x_obs = 0.1*jnp.vstack((jnp.ones(N_data), jnp.cos(theta), jnp.sin(theta))).T
x_obs = x_obs.T/jnp.linalg.norm(x_obs, axis=1)
x_obs = x_obs.T

z_obs = vmap(M.invf)(x_obs)

# %%
xscales = [jnp.min(z_obs[:,0])-0.1, jnp.max(z_obs[:,0])+0.1]
yscales = [jnp.min(z_obs[:,1])-0.1, jnp.max(z_obs[:,1])+0.1]

# %%
n_points = 5
x1 = jnp.linspace(xscales[0], xscales[1], n_points)
x2 = jnp.linspace(yscales[0], yscales[1], n_points)

X1, X2 = jnp.meshgrid(x1,x2)

# %% [markdown]
# ### Riemannian mean

# %%
FrechetMean = GEORCE_FM(M=M,
                        init_fun=None,
                        T=T,
                        max_iter=iters,
                        tol = tol,
                        line_search_params={'rho': rho},
                       )

# %%
fmean_riemannian = FrechetMean(z_obs)

# %%
xt_rgeodesics = vmap(vmap(M.f))(fmean_riemannian[1])
xt_rfm = M.f(fmean_riemannian[0])
rdist = M.length_frechet(fmean_riemannian[1], z_obs, fmean_riemannian[0])

# %%
indicatrix_riemannian = vmap(vmap(lambda u,v: jnp.stack((u,v))+M.indicatrix(jnp.stack((u,v)), N_points=100)/40.0))(X1,X2) #/50#, grid=jnp.linspace(-5,5,1000), eps=1e-6)

# %% [markdown]
# ### Plotting

# %%
from jax import Array
class EllipsoidPlot(ABC):
    def __init__(self, 
                 params=jnp.linspace(0.5,1.0,3),
                ):
        
        self.M = RS2()
        self.force_fun = lambda z: jnp.array([0.75, 0.0])#force_fun(z, self.M)
        self.params = params

    def heat_map(self, X, Y, Z)->Array:
        
        z = vmap(lambda x,y,z: vmap(lambda x1,y1,z1: self.M.invf(jnp.stack((x1,y1,z1))))(x,y,z))(X,Y,Z)
        
        heat_map = vmap(lambda z1: vmap(lambda z: jnp.linalg.norm(self.force_fun(z)))(z1))(z)
        
        return heat_map
    
    def unit_direction(self, n_points:int=100)->Array:
        
        X,Y,Z = self.grid(n_points)
        
        z = vmap(lambda x,y,z: vmap(lambda x1,y1,z1: self.M.invf(jnp.stack((x1,y1,z1))))(x,y,z))(X,Y,Z)
        
        force = vmap(lambda z1: vmap(lambda z: jnp.dot(self.M.Jf(z), self.force_fun(z)))(z1))(z)
        
        return X,Y,Z,force
        
    def grid(self, n_points:int=100)->Array:
        
        theta = jnp.linspace(0.0, jnp.pi*1, n_points)
        phi   = jnp.linspace(0.0, jnp.pi*2, n_points)

        # Creating the coordinate grid for the unit sphere.
        x1 = jnp.outer(jnp.sin(theta), jnp.cos(phi))
        x2 = jnp.outer(jnp.sin(theta), jnp.sin(phi))
        x3 = jnp.outer(jnp.cos(theta), jnp.ones(n_points))
        
        return self.params[0]*x1,self.params[1]*x2,self.params[2]*x3

# %%
class GridPlot(ABC):
    def __init__(self, 
                ):

        return
        
    def grid(self, start_gridx=-2.0, end_gridx=2.0, 
             start_gridy=-2.0, end_gridy=2.0, n_points=100)->Array:
        
        x1 = jnp.linspace(start_gridx, end_gridx, n_points)
        x2 = jnp.linspace(start_gridy, end_gridy, n_points)

        x1, x2 = jnp.meshgrid(x1,x2)
        x3 = jnp.zeros_like(x1)-1.0
        
        return x1, x2, x3

# %%
fig = plt.figure(figsize=(10,10))

#plotting sphere
plot_sphere = EllipsoidPlot(params=jnp.ones(3))
grid_plot = GridPlot()
x1,x2,x3 = plot_sphere.grid(100)
x1_plane, x2_plane, x3_plane = grid_plot.grid(-0.5, 2.8, -1.5,1.5,n_points=100)
field = plot_sphere.unit_direction(10)
ax = fig.add_subplot(111, projection='3d')
obs = vmap(M.f)(z_obs)
def setup_3d_ax(ax):

    # Compute the mean of observed data on the sphere to focus the view
    mean_obs = jnp.mean(obs, axis=0)
    
    # Vector from origin to mean
    vec = mean_obs / jnp.linalg.norm(mean_obs)
    
    # Convert direction vector to spherical coordinates (for elevation and azimuth)
    # azimuth: angle in x-y plane
    azim = jnp.degrees(jnp.arctan2(vec[1], vec[0]))
    # elevation: angle from x-y plane upward
    elev = jnp.degrees(jnp.arcsin(vec[2]))

    ax.plot_surface(
        x1, x2, x3,
        color='lightblue',
        rstride=1, cstride=1,
        alpha=0.3,
        edgecolor='none',
        shade=True
    )
    ax.set_box_aspect([1,1,1])
    ax.set_xlim([-2.0,2.8])
    ax.set_ylim([-2.0,2.8])
    ax.set_zlim([-2.0,2.8])
    ax.set_axis_off()
    ax.view_init(elev=float(elev)+30., azim=float(azim))
setup_3d_ax(ax)
ax.plot_surface(x1_plane, x2_plane, x3_plane, rstride=1, cstride=1, alpha=0.3, color='orange')
ax.scatter(obs[:,0], obs[:,1], obs[:,2], color='black', alpha=1.0, s=100)
ax.scatter(z_obs[:,0], z_obs[:,1], jnp.zeros_like(z_obs[:,0])-1.0, color='black', alpha=1.0, s=100)
ax.scatter(fmean_riemannian[0][0], fmean_riemannian[0][1], -1.0, color='blue', s=250)
mu = M.f(fmean_riemannian[0])
geodesics = vmap(vmap(M.f))(fmean_riemannian[1])
for geo, z_geo in zip(geodesics, fmean_riemannian[1]):
    ax.plot(geo[:,0],
            geo[:,1],
            geo[:,2],
            alpha=1.0,
            linewidth=2.0,
            color='green',
           )
    ax.plot(z_geo[:,0],
            z_geo[:,1],
            -1.0,
            alpha=1.0,
            linewidth=2.0,
            color='green',
           )
ax.scatter(mu[0],mu[1],mu[2],s=250,color='blue',)
for i1, x1,x2 in zip(indicatrix_riemannian, X1, X2):
    for b1, y1, y2 in zip(i1, x1, x2):
        ax.plot(b1[:,0], b1[:,1], -1.0,color='red')
        ax.scatter(y1, y2, -1.0, s=10, color='red')

ax.scatter([],[],[], color="black", alpha=1.0, s=100, label="Data Points")
ax.scatter([],[],[], color="blue", alpha=1.0, s=250, label="Fréchet Mean")
ax.plot([],[],[], color="green", alpha=1.0, linewidth=2.0, label=r"Geodesics")
ax.plot([],[],[], color="red", alpha=1.0, linewidth=2.0, label=r"Indicatrix")

#lines_labels = [ax.get_legend_handles_labels()]
#lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
#fig.legend(lines, labels, loc=(0.225, 0.0), ncol=4, fontsize=50)

fig.tight_layout()

save_path = f'{figure_path}riemannian_chart_conceptual.pdf'
fig.savefig(save_path, format='pdf', pad_inches=0.1, bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Test

# %%
N_data = 10

# %%
M = nSphere(dim=2)

# %%
theta = jnp.linspace(0, 2*jnp.pi, N_data, endpoint=False)
x_obs = 0.1*jnp.vstack((jnp.cos(theta), jnp.sin(theta), jnp.ones(N_data))).T
x_obs = x_obs.T/jnp.linalg.norm(x_obs, axis=1)
x_obs = x_obs.T

z_obs = vmap(M.invf)(x_obs)

# %%
iters = 3
T = 100
tol = 1e-8
rho = 0.5

# %%
FrechetMean = GEORCE_FM(M=M,
                        init_fun=None,
                        T=T,
                        max_iter=iters,
                        tol = tol,
                        line_search_params={'rho': rho},
                       )

# %%
test = FrechetMean(z_obs)

# %%
new_data = test[1][0][::10]

# %%
z_mu = FrechetMean(new_data)[0]

# %%
plt.plot(new_data[:,0], new_data[:,1])
plt.scatter(z_mu[0], z_mu[1])

# %%
from geometry.riemannian.pga.pga import PGA

# %%
pga_model = PGA(M=M,
                init_fun=None,
                T=100,
                max_iter=20,
                tol = 1e-4,
                index_step=1,
                index_tol=1e-4,
                rho=rho,
                epsilon=1e-6,
                pga_method = "exact", #approximation, exact
                orthgornal_method = "projection", #tangent_space, projection
                seed=2712,
               )

# %%
pga_model.fit(new_data, n_components=2)
# Out:
# [[1.79112138e-08 9.88062620e-01]
#  [1.54910946e-08 9.13856387e-01]
#  [1.32347955e-08 8.44719887e-01]
#  [1.11328857e-08 7.79962301e-01]
#  [9.17472853e-09 7.19002247e-01]
#  [7.34946459e-09 6.61345899e-01]
#  [5.64657254e-09 6.06570542e-01]
#  [4.05617495e-09 5.54310977e-01]
#  [2.56918553e-09 5.04249215e-01]
#  [1.17737187e-09 4.56106275e-01]]
# [[7.4759239e-09 6.7464429e-01]
#  [8.5357534e-09 6.9975102e-01]
#  [8.9010568e-09 7.0929867e-01]
#  [8.8622167e-09 7.0847791e-01]
#  [8.8608472e-09 7.0903999e-01]
#  [8.3251912e-09 6.9214666e-01]
#  [8.4475680e-09 6.9671351e-01]
#  [8.4624663e-09 6.9466466e-01]
#  [8.2659630e-09 6.9043398e-01]
#  [8.5807628e-09 6.9365090e-01]]
# [[8.7823429e-09 7.0272923e-01]
#  [8.5425089e-09 6.9981140e-01]
#  [8.8941663e-09 7.0917118e-01]
#  [8.8566487e-09 7.0836657e-01]
#  [8.8549266e-09 7.0891744e-01]
#  [8.3411660e-09 6.9235593e-01]
#  [8.4580938e-09 6.9683331e-01]
#  [8.4740730e-09 6.9482470e-01]
#  [8.2842382e-09 6.9067675e-01]
# ...

# %%
principal_zgeo_backward, principal_zgeo_forward = pga_model.get_principal_geodesics()

# %%
plt.plot(principal_zgeo_backward[0][:,0], principal_zgeo_backward[0][:,1], color='red')
plt.plot(principal_zgeo_forward[0][:,0], principal_zgeo_forward[0][:,1], color='red')
plt.plot(principal_zgeo_backward[1][:,0], principal_zgeo_backward[1][:,1], color='green')
plt.plot(principal_zgeo_forward[1][:,0], principal_zgeo_forward[1][:,1], color='green')
plt.scatter(new_data[:,0], new_data[:,1], color="black")
plt.plot(new_data[:,0], new_data[:,1], color="orange")
plt.xlim(jnp.min(new_data[:,0]), jnp.max(new_data[:,0]))
plt.ylim(jnp.min(new_data[:,1]), jnp.max(new_data[:,1]))
#plt.quiver(z_mu[0], z_mu[1], test2[1][0],test2[1][1])
# Out:
# (0.4561062753200531, 0.9880626201629639)

# %%
from geometry.riemannian.geodesics import GEORCE

# %%
geo = GEORCE(M=M, max_iter=100)

# %%
curve = geo(z_mu, new_data[0])

# %%
plt.plot(curve[:,0], curve[:,1])
plt.plot(new_data[:,0], new_data[:,1], color="orange")

# %%
pga_model = PGA(M=M,
                init_fun=None,
                T=100,
                max_iter=20,
                tol = 1e-4,
                index_step=1,
                index_tol=1e-4,
                rho=rho,
                epsilon=1e-6,
                pga_method = "exact", #approximation, exact
                orthgornal_method = "tangent_space", #tangent_space, projection
                seed=2712,
               )

# %%
new_data = curve[::10]

# %%
pga_model.fit(new_data, n_components=2)
# Out:
# [[8.17504464e-09 6.91891491e-01]
#  [8.97955310e-09 7.18235612e-01]
#  [9.81705561e-09 7.45251656e-01]
#  [1.06898721e-08 7.72983015e-01]
#  [1.16005321e-08 8.01476300e-01]
#  [1.25518032e-08 8.30781579e-01]
#  [1.35467175e-08 8.60952973e-01]
#  [1.45886041e-08 8.92048895e-01]
#  [1.56811240e-08 9.24132466e-01]
#  [1.68283201e-08 9.57272351e-01]]
# (2, 1)
# Hallo
# [[0.99999994]]
# 4.9681472e-09
# End hallo
# [[ 0.12735571  0.81151974]
#  [ 0.10114246  0.81447506]
#  [ 0.07420581  0.81679946]
#  [ 0.04650329  0.8184419 ]
#  [ 0.01802971  0.8193433 ]
#  [-0.01128297  0.8194402 ]
#  [-0.04144043  0.8186603 ]
#  [-0.07250451  0.81692207]
#  [-0.10449117  0.8141358 ]
#  [-0.13745299  0.8101975 ]]
# (2, 2)
# Hallo
# [[0.99999994 0.00256307]
#  [0.00256307 1.0000001 ]]
# -0.30535567
# End hallo
# [[ 2.5995329e-04  5.9109020e-01]
#  [ 2.1566372e-04  6.3443613e-01]
#  [ 1.6575483e-04  6.8073100e-01]
#  [ 1.0916350e-04  7.3044240e-01]
#  [ 4.4640354e-05  7.8406340e-01]
# ...

# %%
principal_zgeo_backward, principal_zgeo_forward = pga_model.get_principal_geodesics()

# %%
principal_zgeo_backward[1][:,0]
# Out:
# Array([0.01121336, 0.02242609, 0.03363717, 0.04484558, 0.05605027,
#        0.06725024, 0.07844441, 0.08963178, 0.1008113 , 0.11198194,
#        0.12314264, 0.13429238, 0.1454301 , 0.15655476, 0.1676653 ,
#        0.17876068, 0.18983983, 0.20090169, 0.21194519, 0.22296928,
#        0.23397286, 0.24495487, 0.2559142 , 0.26684985, 0.27776062,
#        0.2886455 , 0.29950333, 0.310333  , 0.32113343, 0.3319035 ,
#        0.34264207, 0.353348  , 0.36402017, 0.37465745, 0.38525867,
#        0.39582267, 0.40634835, 0.41683444, 0.42727986, 0.4376834 ,
#        0.44804385, 0.45836005, 0.4686308 , 0.47885484, 0.48903105,
#        0.49915814, 0.50923496, 0.5192602 , 0.52923274, 0.5391512 ,
#        0.54901445, 0.55882114, 0.56857014, 0.57826006, 0.5878898 ,
#        0.59745795, 0.6069633 , 0.61640453, 0.6257805 , 0.6350898 ,
#        0.6443312 , 0.65350354, 0.6626053 , 0.6716354 , 0.6805925 ,
#        0.6894753 , 0.6982826 , 0.7070131 , 0.71566546, 0.7242386 ,
# ...

# %%
#plt.plot(principal_zgeo_backward[0][:,0], principal_zgeo_backward[0][:,1], color='red')
#plt.plot(principal_zgeo_forward[0][:,0], principal_zgeo_forward[0][:,1], color='red')
plt.plot(principal_zgeo_backward[1][:,0], principal_zgeo_backward[1][:,1], color='green')
plt.plot(principal_zgeo_forward[1][:,0], principal_zgeo_forward[1][:,1], color='green')
plt.scatter(new_data[:,0], new_data[:,1], color="black")
plt.plot(new_data[:,0], new_data[:,1], color="orange")
#plt.xlim(jnp.min(new_data[:,0]), jnp.max(new_data[:,0]))
#plt.ylim(jnp.min(new_data[:,1]), jnp.max(new_data[:,1]))
#plt.quiver(z_mu[0], z_mu[1], test2[1][0],test2[1][1])

# %%
curve[::10]
# Out:
# Array([[8.0971114e-09, 6.8931842e-01],
#        [8.1049762e-09, 6.8957818e-01],
#        [8.1128420e-09, 6.8983793e-01],
#        [8.1207103e-09, 6.9009775e-01],
#        [8.1285796e-09, 6.9035763e-01],
#        [8.1364506e-09, 6.9061750e-01],
#        [8.1443234e-09, 6.9087744e-01],
#        [8.1521980e-09, 6.9113737e-01],
#        [8.1600744e-09, 6.9139743e-01],
#        [8.1679525e-09, 6.9165742e-01]], dtype=float32)

# %%
from geometry.riemannian.geodesics import GEORCE

# %%
z0 = -jnp.linspace(0,1,2)
zT = 0.5*jnp.ones(2, dtype=jnp.float32)

# %%
geo = GEORCE(M=M, max_iter=100)
curve = geo(z0,zT)
data = curve[::10]

# %%
plt.plot(curve[:,0], curve[:,1])

# %%
pga_model = PGA(M=M,
                init_fun=None,
                T=100,
                max_iter=20,
                tol = 1e-4,
                index_step=1,
                index_tol=1e-4,
                rho=rho,
                epsilon=1e-6,
                pga_method = "exact", #approximation, exact
                orthgornal_method = "projection", #tangent_space, projection
                seed = 2712,
               )

# %%
new_data = curve[::10]

# %%
pga_model.fit(new_data, n_components=2)
# Out:
# [[ 0.02051456 -0.9894739 ]
#  [ 0.20258483 -0.8696653 ]
#  [ 0.34561187 -0.731334  ]
#  [ 0.4542345  -0.5825159 ]
#  [ 0.532766   -0.42810464]
#  [ 0.5846499  -0.27095068]
#  [ 0.61229366 -0.11265773]
#  [ 0.6170513   0.04585314]
#  [ 0.59924775  0.20392478]
#  [ 0.5581974   0.3608073 ]]
# (2, 1)
# Hallo
# [[0.99999994]]
# 0.57608306
# End hallo
# [[ 1.2655101   0.20879096]
#  [ 1.1006569  -0.00662062]
#  [ 0.9383621  -0.15235825]
#  [ 0.7845758  -0.25332054]
#  [ 0.63842165 -0.32391134]
#  [ 0.49746558 -0.37216288]
#  [ 0.35912633 -0.40242225]
#  [ 0.22094762 -0.41676858]
#  [ 0.08047938 -0.415595  ]
#  [-0.06489497 -0.39771324]]
# (2, 2)
# Hallo
# [[ 0.99999994 -0.5678342 ]
#  [-0.5678342   1.        ]]
# -1.8411676
# End hallo
# [[-0.90236795 -0.99482405]
#  [-0.349686   -1.079743  ]
#  [ 0.06248714 -0.95299536]
#  [ 0.34182033 -0.73853666]
#  [ 0.5179481  -0.48824722]
#  [ 0.6113252  -0.22206077]
#  [ 0.63099986  0.05202057]
#  [ 0.576123    0.32907888]
# ...

# %%
principal_zgeo_backward, principal_zgeo_forward = pga_model.get_principal_geodesics()

# %%
plt.plot(principal_zgeo_backward[0][:,0], principal_zgeo_backward[0][:,1], color='red')
plt.plot(principal_zgeo_forward[0][:,0], principal_zgeo_forward[0][:,1], color='red')
plt.plot(principal_zgeo_backward[1][:,0], principal_zgeo_backward[1][:,1], color='green')
plt.plot(principal_zgeo_forward[1][:,0], principal_zgeo_forward[1][:,1], color='green')
plt.scatter(new_data[:,0], new_data[:,1], color="black")
plt.plot(new_data[:,0], new_data[:,1], color="orange")
#plt.xlim(jnp.min(new_data[:,0]), jnp.max(new_data[:,0]))
#plt.ylim(jnp.min(new_data[:,1]), jnp.max(new_data[:,1]))
#plt.quiver(z_mu[0], z_mu[1], test2[1][0],test2[1][1])
